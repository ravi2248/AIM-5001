# %% [markdown]
# ### Question 1

# %% [markdown]
# To solve this question, first, we need to create a project named <b>'AIM 5001'</b> in the Neo4j desktop and also need to create a local DBMS named <b>'Final Exam Q1'</b>. After that we need to start the local DBMS and open the Neo4j browser.

# %% [markdown]
# ![1.png](attachment:1.png)

# %% [markdown]
# First, we need to create nodes for Users. We created nodes like Modesto, Ayine, Christopher, Cheong woo, Saulat, and Heidy by using CREATE command.<br>
# We can see the commands below.<br>
# CREATE (modesto:User {name: "Modesto"})<br>
# CREATE (ayine:User {name: "Ayine"})<br>
# CREATE (christopher:User {name: "Christopher"})<br>
# CREATE (cheongWoo:User {name: "Cheong woo"})<br>
# CREATE (saulat:User {name: "Saulat"})<br>
# CREATE (heidy:User {name: "Heidy"})

# %% [markdown]
# ![2.png](attachment:2.png)

# %% [markdown]
# <b>Result:</b><br>
# From the above screenshot, we can see that the above commands gave output. It added 6 labels, created 6 nodes, and set 6 properties.<br><br>

# %% [markdown]
# We need to create nodes for Group. We created nodes like I.T., Sales, Administration, and Operations by using CREATE command.<br>
# We can see the commands below.<br>
# CREATE (it:Group {name: "I.T."})<br>
# CREATE (sales:Group {name: "Sales"})<br>
# CREATE (administration:Group {name: "Administration"})<br>
# CREATE (operations:Group {name: "Operations"})

# %% [markdown]
# ![3.png](attachment:3.png)

# %% [markdown]
# <b>Result:</b><br>
# From the above screenshot, we can see that the above commands gave output. It added 4 labels, created 4 nodes, and set 4 properties.<br><br>

# %% [markdown]
# We need to create nodes for Room. We created nodes like Room 101, Room 102, Auditorium A, Auditorium B, and Admin by using CREATE command.<br>
# We can see the commands below.<br>
# CREATE (room101:Room {name: "Room 101"})<br>
# CREATE (room102:Room {name: "Room 102"})<br>
# CREATE (auditoriumA:Room {name: "Auditorium A"})<br>
# CREATE (auditoriumB:Room {name: "Auditorium B"})<br>
# CREATE (adminRoom:Room {name: "Admin"})

# %% [markdown]
# ![4.png](attachment:4.png)

# %% [markdown]
# <b>Result:</b><br>
# From the above screenshot, we can see that the above commands gave output. It added 5 labels, created 5 nodes, and set 5 properties.<br><br>

# %% [markdown]
# We need to make relationship between Modesto and I.T. The below command will find a node named Modesto which is labeled as User and a node named I.T. which is labeled as Group and create a relationship named MEMBER_OF.<br>
# MATCH (user:User {name: "Modesto"}), (group:Group {name: "I.T."})<br>
# CREATE (user)-[:MEMBER_OF]->(group)

# %% [markdown]
# ![5.png](attachment:5.png)

# %% [markdown]
# <b>Result:</b><br>
# From the above screenshot, we can see that the above commands gave output. It created a relationship named MEMBER_OF.<br><br>

# %% [markdown]
# We need to make relationship between Ayine and I.T. The below command will find a node named Ayine which is labeled as User and a node named I.T. which is labeled as Group and create a relationship named MEMBER_OF.<br>
# MATCH (user:User {name: "Ayine"}), (group:Group {name: "I.T."})<br>
# CREATE (user)-[:MEMBER_OF]->(group)

# %% [markdown]
# ![6.png](attachment:6.png)

# %% [markdown]
# <b>Result:</b><br>
# From the above screenshot, we can see that the above commands gave output. It created a relationship named MEMBER_OF.<br><br>

# %% [markdown]
# We need to make relationship between Christopher and Sales. The below command will find a node named Christopher which is labeled as User and a node named Sales which is labeled as Group and create a relationship named MEMBER_OF.<br>
# MATCH (user:User {name: "Christopher"}), (group:Group {name: "Sales"})<br>
# CREATE (user)-[:MEMBER_OF]->(group)

# %% [markdown]
# ![7.png](attachment:7.png)

# %% [markdown]
# <b>Result:</b><br>
# From the above screenshot, we can see that the above commands gave output. It created a relationship named MEMBER_OF.<br><br>

# %% [markdown]
# We need to make relationship between Cheong woo and Sales. The below command will find a node named Cheong woo which is labeled as User and a node named Sales which is labeled as Group and create a relationship named MEMBER_OF.<br>
# MATCH (user:User {name: "Cheong woo"}), (group:Group {name: "Sales"})<br>
# CREATE (user)-[:MEMBER_OF]->(group)

# %% [markdown]
# ![8.png](attachment:8.png)

# %% [markdown]
# <b>Result:</b><br>
# From the above screenshot, we can see that the above commands gave output. It created a relationship named MEMBER_OF.<br><br>

# %% [markdown]
# We need to make relationship between Saulat and Administration. The below command will find a node named Saulat which is labeled as User and a node named Administration which is labeled as Group and create a relationship named MEMBER_OF.<br>
# MATCH (user:User {name: "Saulat"}), (group:Group {name: "Administration"})<br>
# CREATE (user)-[:MEMBER_OF]->(group)

# %% [markdown]
# ![9.png](attachment:9.png)

# %% [markdown]
# <b>Result:</b><br>
# From the above screenshot, we can see that the above commands gave output. It created a relationship named MEMBER_OF.<br><br>

# %% [markdown]
# We need to make relationship between I.T. and Room 101. The below command will find a node named I.T. which is labeled as Group and a node named Room 101 which is labeled as Room and create a relationship named HAS_ACCESS.<br>
# MATCH (group:Group {name: "I.T."}), (room:Room {name: "Room 101"})<br>
# CREATE (group)-[:HAS_ACCESS]->(room)

# %% [markdown]
# ![10.png](attachment:10.png)

# %% [markdown]
# <b>Result:</b><br>
# From the above screenshot, we can see that the above commands gave output. It created a relationship named HAS_ACCESS.<br><br>

# %% [markdown]
# We need to make relationship between I.T. and Room 102. The below command will find a node named I.T. which is labeled as Group and a node named Room 102 which is labeled as Room and create a relationship named HAS_ACCESS.<br>
# MATCH (group:Group {name: "I.T."}), (room:Room {name: "Room 102"})<br>
# CREATE (group)-[:HAS_ACCESS]->(room)

# %% [markdown]
# ![11.png](attachment:11.png)

# %% [markdown]
# <b>Result:</b><br>
# From the above screenshot, we can see that the above commands gave output. It created a relationship named HAS_ACCESS.<br><br>

# %% [markdown]
# We need to make relationship between Sales and Room 102. The below command will find a node named Sales which is labeled as Group and a node named Room 102 which is labeled as Room and create a relationship named HAS_ACCESS.<br>
# MATCH (group:Group {name: "Sales"}), (room:Room {name: "Room 102"})<br>
# CREATE (group)-[:HAS_ACCESS]->(room)

# %% [markdown]
# ![12.png](attachment:12.png)

# %% [markdown]
# <b>Result:</b><br>
# From the above screenshot, we can see that the above commands gave output. It created a relationship named HAS_ACCESS.<br><br>

# %% [markdown]
# We need to make relationship between Sales and Auditorium B. The below command will find a node named Sales which is labeled as Group and a node named Auditorium B which is labeled as Room and create a relationship named HAS_ACCESS.<br>
# MATCH (group:Group {name: "Sales"}), (room:Room {name: "Auditorium B"})<br>
# CREATE (group)-[:HAS_ACCESS]->(room)

# %% [markdown]
# ![13.png](attachment:13.png)

# %% [markdown]
# <b>Result:</b><br>
# From the above screenshot, we can see that the above commands gave output. It created a relationship named HAS_ACCESS.<br><br>

# %% [markdown]
# We need to make relationship between Administration and Room 101. The below command will find a node named Administration which is labeled as Group and a node named Room 101 which is labeled as Room and create a relationship named HAS_ACCESS.<br>
# MATCH (group:Group {name: "Administration"}), (room:Room {name: "Room 101"})<br>
# CREATE (group)-[:HAS_ACCESS]->(room)

# %% [markdown]
# ![14.png](attachment:14.png)

# %% [markdown]
# <b>Result:</b><br>
# From the above screenshot, we can see that the above commands gave output. It created a relationship named HAS_ACCESS.<br><br>

# %% [markdown]
# We need to make relationship between Administration and Admin. The below command will find a node named Administration which is labeled as Group and a node named Admin which is labeled as Room and create a relationship named HAS_ACCESS.<br>
# MATCH (group:Group {name: "Administration"}), (room:Room {name: "Admin"})<br>
# CREATE (group)-[:HAS_ACCESS]->(room)

# %% [markdown]
# ![15.png](attachment:15.png)

# %% [markdown]
# <b>Result:</b><br>
# From the above screenshot, we can see that the above commands gave output. It created a relationship named HAS_ACCESS.<br><br>

# %% [markdown]
# We need to make relationship between Operations and all Rooms. The below command will find a node named Operations which is labeled as Group and all the nodes which is labeled as Room and create a relationship named HAS_ACCESS.<br>
# MATCH (group:Group {name: "Operations"}), (room:Room)<br>
# CREATE (group)-[:HAS_ACCESS]->(room)

# %% [markdown]
# ![16.png](attachment:16.png)

# %% [markdown]
# <b>Result:</b><br>
# From the above screenshot, we can see that the above commands gave output. It created 5 relationships named HAS_ACCESS.<br><br>

# %% [markdown]
# We can see the graph by using the below command.<br>
# MATCH (n)<br>
# RETURN n

# %% [markdown]
# ![17.png](attachment:17.png)

# %% [markdown]
# ![graph.png](attachment:graph.png)

# %% [markdown]
# <b>Result:</b><br>
# From the above graph model, we can see that Ayine and Modesto are in the same group named I.T. Christopher and Cheong woo are in the Sales group. Saulat is in the Admistration group. Heidy is not get assigned any group. I.T has access of Room 101 and Room 102. Sales has access of Room 102 and Auditorium B. Administration has access of Room 101 and Admin. Operations has access of all rooms.<br><br>
